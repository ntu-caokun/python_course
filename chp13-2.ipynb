# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# • pandas主要提供了3种数据结构:1) Series,带标签的一维数组;2)
#
# DataFrame,带标签且大小可变的二维表格结构;3)Panel,带标签且大小
# 可变的三维数组。

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (1)生成一维数组

# %%
import numpy as np
import pandas as pd
x = pd.Series([1, 3, 5, np.nan])
print(x)

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
print(pd.date_range(start='20130101', end='20131231', freq='H'))

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
dates = pd.date_range(start='20130101', end='20131231', freq='D')
# 间隔为天
print(dates)

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
dates = pd.date_range(start='20130101', end='20131231', freq='M')
# 间隔为月
print(dates)

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
print(pd.period_range('20170601', '20170630', freq='W'))
print(pd.period_range('20170601', '20170630', freq='D'))

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
print(pd.period_range('20170601', '20170630', freq='H'))

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (2)生成DataFrame

# %%
print(pd.DataFrame(np.random.randn(12,4), index=dates, columns=list('ABCD')))

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
# 4列随机数
print(pd.DataFrame([np.random.randint(1, 100, 4) for i in range(12)], index=dates, columns=list('ABCD')))

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
print(pd.DataFrame({
    'A': np.random.randint(1, 100, 4),
    'C': pd.Series([1, 2, 3, 4], index=list(range(4)), dtype='float32'),
    'B': pd.date_range(start='20130101', periods=4, freq='D'),
    'D': np.array([3] * 4, dtype='int32'),
    'E': pd.Categorical(["test", "train", "test", "train"]),
    'F': 'foo'
}))

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
df = pd.DataFrame({
    'A': np.random.randint(1, 100, 4),
    'B': pd.date_range(start='20130101', periods=4, freq='D'),
    'C': pd.Series([1, 2, 3, 4], index=['zhang', 'li', 'zhou', 'wang'], dtype='float32'),
    'D': np.array([3] * 4, dtype='int32'),
    'E': pd.Categorical(["test", "train", "test", "train"]),
    'F': 'foo'
})
print(df)

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (3)二维数据查看

# %%
# 默认显示前5行
print(df.head())
# 查看前3行
print(df.head(3))
# 查看最后2行
print(df.tail(2))

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (4)查看二维数据的索引、列名和数据

# %%
print(df.index)
print(df.columns)
print(df.values)

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (5)查看数据的统计信息

# %%
# 平均值、标准差、最小值、最大值等信息
print(df.describe())

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (6)二维数据转置

# %%
print(df.T)

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (7)排序

# %%
print(df.sort_index(axis=0, ascending=False))
# 对轴进行排序
print(df.sort_index(axis=0, ascending=True))

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
print(df.sort_index(axis=1, ascending=False))
# 对数据进行排序
print(df.sort_values(by='A'))
# 也可以使用by=['A','B']按多列进行排序

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (8)数据选择

# %%
print(df['A'])
print(69 in df['A'])
print(69 in df['A'].values)
# 选择列

# %% [markdown]
# ### 13.3 数据分析模块pandas

# %%
# 查询第1行第2列位置的数据值
print(df.iloc[0, 1])
# 查询第3行第3列位置的数据值
print(df.iloc[2, 2])
# 按给定条件进行查询
print(df[df.A > 50])
# 按给定条件进行查询
print(df[df['E'] == 'test'])
print(df[df['A'].isin([20, 69])])

# %% [markdown]
# ### 13.3 数据分析模块pandas
#
# (9)数据修改

# %%
df.iat[0, 2] = 3
# 修改指定行、列位置的数据值
df.loc[:, 'D'] = np.random.randint(50, 60, 4)
# 修改某列的值
df['C'] = -df['C']
# 对指定列数据取反
print(df)
